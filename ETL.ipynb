# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
file = "xweather.csv"

# %%
df = pd.read_csv(file)
pd.set_option('display.max_columns', None)
df
# Out:
#            pickup_datetime  tempm  tempi  dewptm  dewpti   hum  wspdm  wspdi  \
# 0      2015-12-31 00:15:00    7.8   46.0     6.1    43.0  89.0    7.4    4.6
# 1      2015-12-31 00:42:00    7.8   46.0     6.1    43.0  89.0    7.4    4.6
# 2      2015-12-31 00:51:00    7.8   46.0     6.1    43.0  89.0    5.6    3.5
# 3      2015-12-31 01:51:00    7.2   45.0     5.6    42.1  90.0    7.4    4.6
# 4      2015-12-31 02:51:00    7.2   45.0     5.6    42.1  90.0    0.0    0.0
# 5      2015-12-31 03:28:00    6.7   44.1     5.0    41.0  89.0    7.4    4.6
# 6      2015-12-31 03:40:00    7.2   45.0     5.0    41.0  86.0    0.0    0.0
# 7      2015-12-31 03:51:00    7.2   45.0     5.0    41.0  86.0    7.4    4.6
# 8      2015-12-31 04:22:00    7.2   45.0     5.0    41.0  86.0    5.6    3.5
# 9      2015-12-31 04:51:00    7.2   45.0     5.6    42.1  90.0    5.6    3.5
# 10     2015-12-31 05:14:00    7.2   45.0     5.0    41.0  86.0    0.0    0.0
# ...

# %%
new_df = df.drop(columns=['tempm', 'dewptm','wspdm','wgustm','vism', 'precipi','windchilli','pressurem','windchillm','wgusti', 'wgustm','heatindexm','heatindexi','precipm','icon'])

# %%
new_df
# Out:
#            pickup_datetime  tempi  dewpti   hum  wspdi  wdird     wdire  visi  \
# 0      2015-12-31 00:15:00   46.0    43.0  89.0    4.6     40        NE   2.5
# 1      2015-12-31 00:42:00   46.0    43.0  89.0    4.6      0  Variable   4.0
# 2      2015-12-31 00:51:00   46.0    43.0  89.0    3.5     20       NNE   5.0
# 3      2015-12-31 01:51:00   45.0    42.1  90.0    4.6      0  Variable   8.0
# 4      2015-12-31 02:51:00   45.0    42.1  90.0    0.0      0     North   8.0
# 5      2015-12-31 03:28:00   44.1    41.0  89.0    4.6    300       WNW   8.0
# 6      2015-12-31 03:40:00   45.0    41.0  86.0    0.0      0     North   8.0
# 7      2015-12-31 03:51:00   45.0    41.0  86.0    4.6    310        NW   9.0
# 8      2015-12-31 04:22:00   45.0    41.0  86.0    3.5    280      West   9.0
# 9      2015-12-31 04:51:00   45.0    42.1  90.0    3.5    270      West   7.0
# 10     2015-12-31 05:14:00   45.0    41.0  86.0    0.0      0     North   8.0
# ...

# %%
figsi
new_df.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-05bfc8420f41> in <module>
# ----> 1 figsi
#       2 new_df.plot.hist(grid=True, bins=20, rwidth=0.9,
#       3                    color='green')
#
# NameError: name 'figsi' is not defined

# %%
replaced_df=new_df.replace({'fog': {0:'No', 1:'Yes'},
                'rain': {0:'No', 1:'Yes'},
                 'snow': {0:'No', 1:'Yes'},
                  'hail': {0:'No', 1:'Yes'},
                   'thunder': {0:'No', 1:'Yes'},
                    'tornado': {0:'No', 1:'Yes'}})
replaced_df
# Out:
#            pickup_datetime  tempi  dewpti   hum  wspdi  wdird     wdire  visi  \
# 0      2015-12-31 00:15:00   46.0    43.0  89.0    4.6     40        NE   2.5
# 1      2015-12-31 00:42:00   46.0    43.0  89.0    4.6      0  Variable   4.0
# 2      2015-12-31 00:51:00   46.0    43.0  89.0    3.5     20       NNE   5.0
# 3      2015-12-31 01:51:00   45.0    42.1  90.0    4.6      0  Variable   8.0
# 4      2015-12-31 02:51:00   45.0    42.1  90.0    0.0      0     North   8.0
# 5      2015-12-31 03:28:00   44.1    41.0  89.0    4.6    300       WNW   8.0
# 6      2015-12-31 03:40:00   45.0    41.0  86.0    0.0      0     North   8.0
# 7      2015-12-31 03:51:00   45.0    41.0  86.0    4.6    310        NW   9.0
# 8      2015-12-31 04:22:00   45.0    41.0  86.0    3.5    280      West   9.0
# 9      2015-12-31 04:51:00   45.0    42.1  90.0    3.5    270      West   7.0
# 10     2015-12-31 05:14:00   45.0    41.0  86.0    0.0      0     North   8.0
# ...

# %%
replaced_df.to_csv("pleasewhether.csv", index=False)
