# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Load in file

data = "C:/Users/Walid/Documents/Columbia/data/NYPD_Complaint_Data_Historic_bkp.csv"

df = pd.read_csv(data)
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
# Dropping unwanted columns 

df1 = df[["CMPLNT_NUM", "CMPLNT_FR_DT", "RPT_DT", "KY_CD", "OFNS_DESC", "PD_CD", "ADDR_PCT_CD", "LOC_OF_OCCUR_DESC","PREM_TYP_DESC", "X_COORD_CD","Y_COORD_CD","Latitude", "Longitude", "Lat_Lon"  ]]
df1
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT      RPT_DT  KY_CD  \
# 0         101109527   12/31/2015  12/31/2015    113
# 1         153401121   12/31/2015  12/31/2015    101
# 2         569369778   12/31/2015  12/31/2015    117
# 3         968417082   12/31/2015  12/31/2015    344
# 4         641637920   12/31/2015  12/31/2015    344
# 5         365661343   12/31/2015  12/31/2015    106
# 6         608231454   12/31/2015  12/31/2015    235
# 7         265023856   12/31/2015  12/31/2015    118
# 8         989238731   12/31/2015  12/31/2015    344
# 9         415095955   12/31/2015  12/31/2015    341
# 10        731283092   12/31/2015  12/31/2015    341
# 11        178090167   12/31/2015  12/31/2015    341
# 12        898496564   12/31/2015  12/31/2015    109
# 13        566081066   12/31/2015  12/31/2015    109
# 14        584555879   12/31/2015  12/31/2015    113
# 15        715942154   12/31/2015  12/31/2015    105
# 16        338440707   12/31/2015  12/31/2015    109
# ...

# %%
# More data table checks

#df1.dtypes
#df1.isnull().sum()
df1 = df1.fillna("NaN")
df1.head()
# Out:
#     Crime_ID Occurence_Date Report_Date  Offense_Code  \
# 0  101109527     12/31/2015  12/31/2015           113
# 1  153401121     12/31/2015  12/31/2015           101
# 2  569369778     12/31/2015  12/31/2015           117
# 3  968417082     12/31/2015  12/31/2015           344
# 4  641637920     12/31/2015  12/31/2015           344
#
#                      Offense_Desc. Police_Department_Code Police_Precinct  \
# 0                          FORGERY                    729              44
# 1  MURDER & NON-NEGL. MANSLAUGHTER                    NaN             103
# 2                  DANGEROUS DRUGS                    503              28
# 3     ASSAULT 3 & RELATED OFFENSES                    101             105
# 4     ASSAULT 3 & RELATED OFFENSES                    101              13
#
#    Location   Location_Desc. X_Coordinate Y_Coordinate Latitude Longitude  \
# 0    INSIDE   BAR/NIGHT CLUB  1.00731e+06       241257  40.8288  -73.9167
# ...

# %%
# Renaming columns

df1 = df1.rename(columns={"CMPLNT_NUM" : "Crime_ID",
                          "CMPLNT_FR_DT" : "Occurence_Date", 
                          "RPT_DT" : "Report_Date", 
                          "KY_CD" : "Offense_Code",
                          "OFNS_DESC" : "Offense_Desc.",
                          "PD_CD" : "Police_Department_Code",
                          "ADDR_PCT_CD" : "Police_Precinct",
                          "LOC_OF_OCCUR_DESC" : "Location",
                          "PREM_TYP_DESC" : "Location_Desc.",
                          "X_COORD_CD": "X_Coordinate",
                          "Y_COORD_CD" : "Y_Coordinate",
                          "Lat_Lon" : "Lat_&_Lon",
                    })

df1.head()
# Out:
#     Crime_ID Occurence_Date Report_Date  Offense_Code  \
# 0  101109527     12/31/2015  12/31/2015           113
# 1  153401121     12/31/2015  12/31/2015           101
# 2  569369778     12/31/2015  12/31/2015           117
# 3  968417082     12/31/2015  12/31/2015           344
# 4  641637920     12/31/2015  12/31/2015           344
#
#                      Offense_Desc.  Police_Department_Code  Police_Precinct  \
# 0                          FORGERY                   729.0             44.0
# 1  MURDER & NON-NEGL. MANSLAUGHTER                     NaN            103.0
# 2                  DANGEROUS DRUGS                   503.0             28.0
# 3     ASSAULT 3 & RELATED OFFENSES                   101.0            105.0
# 4     ASSAULT 3 & RELATED OFFENSES                   101.0             13.0
#
#    Location   Location_Desc.  X_Coordinate  Y_Coordinate   Latitude  \
# 0    INSIDE   BAR/NIGHT CLUB     1007314.0      241257.0  40.828848
# ...

# %%
#df1["Occurence_Date"] = pd.to_numeric(df1["Occurence_Date"])

#df1.loc[dt.Occurence_Date(year=2015,month=1,day=1):dt.Occurence_Date(year=2015,month=12,day=31)]


#df['CMPLNT_FR_DT'] = pd.to_datetime(df['CMPLNT_FR_DT'])

#include = df[df['CMPLNT_FR_DT'].dt.2015 == 2015]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "12/31/2015"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-5b67130ece15> in <module>
# ----> 1 df1["Occurence_Date"] = pd.to_numeric(df1["Occurence_Date"])
#       2
#       3
#       4 df1.loc[dt.Occurence_Date(year=2015,month=1,day=1):dt.Occurence_Date(year=2015,month=12,day=31)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# ...

# %%
#df.loc[dt.CMPLNT_FR_DT(year=2015,month=1,day=1):dt.CMPLNT_FR_DT(year=2015,month=12,day=31)]
